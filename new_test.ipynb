# %%
from make_monotone import make_mono
from stopping_points import *
from status import Status
from graph_struct import *

# %%
v1 = Vertex(-8,0, 1)
v2 = Vertex(-7,-4, 2)
v3 = Vertex(-1,-9, 3)
v4 = Vertex(-4,-4, 4)
v5 = Vertex(2,-10, 5)
v6 = Vertex(4, -8, 6)
v7 = Vertex(1,-7,7)
v8 = Vertex(8, -6, 8)
v9 = Vertex(3,-3,9)
v10 = Vertex(2,2,10)
v11 = Vertex(-4,4,11)
v12 = Vertex(-3, -1, 12)
v13 = Vertex(-5,1,13)

# %%
p = Polygon(v1, v2, v3)
p.add_vertex(v4)
p.add_vertex(v5)
p.add_vertex(v6)
p.add_vertex(v7)
p.add_vertex(v8)
p.add_vertex(v9)
p.add_vertex(v10)
p.add_vertex(v11)
p.add_vertex(v12)
p.add_vertex(v13)

# %%
p.create_graph()

# %%
graph = make_mono(p)
# Out:
# 1  is the current node
# in start start
# Current:  (1, 2), (1, 13)
# 2  is the current node
# in lower
# testing  (1, 2) (1, 13)
# Returning 1 (1, 13)
# Current:  (2, 3), (1, 13)
# 13  is the current node
# in upper
# edge removed in upper,  (1, 13)
# Current:  (2, 3), (13, 12)
# 4  is the current node
# in split
# testing  (2, 3) (13, 12)
# Returning 1 (13, 12)
# names of edges we connect  4 13
# Current:  (2, 3), (4, 3), (4, 5), (13, 12)
# 11  is the current node
# in start start
# Current:  (2, 3), (4, 3), (4, 5), (13, 12), (11, 12), (11, 10)
# 12  is the current node
# in merge
# testing  (2, 3) (4, 3)
# testing  (4, 3) (4, 5)
# testing  (4, 5) (13, 12)
# testing  (13, 12) (11, 12)
# testing  (11, 12) (11, 10)
# Returning 5 (11, 10)
# helper found for merge is  (-4.000000, 4.000000)
# Current:  (2, 3), (4, 3), (4, 5), (11, 10)
# 3  is the current node
# in end 3
# 2 (4, 5) (4, 3)
# less
# 1
# (4, 3)
# 2 (4, 5) (4, 3)
# less
# 1
# (4, 3)
# Current:  (4, 5), (11, 10)
# 7  is the current node
# in split
# testing  (4, 5) (11, 10)
# Returning 1 (11, 10)
# names of edges we connect  7 12
# Current:  (4, 5), (7, 6), (7, 8), (11, 10)
# 5  is the current node
# in lower
# testing  (4, 5) (7, 6)
# Returning 1 (7, 6)
# 3 (11, 10) (4, 5)
# less
# 2
# (7, 8)
# 1
# (7, 6)
# 0
# (4, 5)
# Current:  (5, 6), (7, 6), (7, 8), (11, 10)
# 10  is the current node
# in upper
# edge removed in upper,  (11, 10)
# Current:  (5, 6), (7, 6), (7, 8), (10, 9)
# 9  is the current node
# in upper
# edge removed in upper,  (10, 9)
# Current:  (5, 6), (7, 6), (7, 8), (9, 8)
# 6  is the current node
# in end 6
# Current:  (7, 8), (9, 8)
# 8  is the current node
# in end 8
# Current:

# %%
nx.draw(graph, nx.get_node_attributes(graph, 'pos'), with_labels=True, node_size=0)
plt.show()

# %%
print(p.vertices[3])
# Out:
# (-4.000000, -4.000000)

# %%
print(p.vertices[3].v_prev)
# Out:
# (-1.000000, -9.000000)

# %%
v1 = Vertex(-3,1, 1)
v2 = Vertex(0,0, 2)
v3 = Vertex(3,4, 3)
v4 = Vertex(-2,5, 4)
v5 = Vertex(-1,2, 5)


p = Polygon(v1, v2, v3)
p.add_vertex(v4)
p.add_vertex(v5)

# %%
p.create_graph()

# %%
graph = make_mono(p)
# Out:
# 1  is the current node
# in start start
# Current:  (1, 2), (1, 5)
# 4  is the current node
# in start start
# Current:  (1, 2), (1, 5), (4, 5), (4, 3)
# 5  is the current node
# in merge
# testing  (1, 2) (1, 5)
# testing  (1, 5) (4, 5)
# testing  (4, 5) (4, 3)
# Returning 3 (4, 3)
# helper found for merge is  (-2.000000, 5.000000)
# Current:  (1, 2), (4, 3)
# 2  is the current node
# in lower
# testing  (1, 2) (4, 3)
# Returning 1 (4, 3)
# Current:  (2, 3), (4, 3)
# 3  is the current node
# in end 3
# Current:

# %%
nx.draw(graph, nx.get_node_attributes(graph, 'pos'), with_labels=True, node_size=0)
plt.show()
