# %%
from make_monotone import make_mono
from stopping_points import *
from status import Status
from graph_struct import *

# %%
v1 = Vertex(-8,0, 1)
v2 = Vertex(-7,-4, 2)
v3 = Vertex(-1,-9, 3)
v4 = Vertex(-4,-4, 4)
v5 = Vertex(2,-10, 5)
v6 = Vertex(4, -8, 6)
v7 = Vertex(1,-7,7)
v8 = Vertex(8, -6, 8)
v9 = Vertex(3,-3,9)
v10 = Vertex(2,2,10)
v11 = Vertex(-4,4,11)
v12 = Vertex(-3, -1, 12)
v13 = Vertex(-5,1,13)

# %%
p = Polygon(v1, v2, v3)
p.add_vertex(v4)
p.add_vertex(v5)
p.add_vertex(v6)
p.add_vertex(v7)
p.add_vertex(v8)
p.add_vertex(v9)
p.add_vertex(v10)
p.add_vertex(v11)
p.add_vertex(v12)
p.add_vertex(v13)

# %%
p.create_graph()

# %%
graph = make_mono(p)
# Out:
# 1  is the current node
# Current:  (1, 2), (1, 13)
# 2  is the current node
# in lower
# should find edge (1, 13)
# edge helper 1 start
# Current:  (2, 3), (1, 13)
# 13  is the current node
# Current:  (2, 3), (13, 12)
# 4  is the current node
# Current:  (2, 3), (4, 3), (4, 5), (13, 12)
# 11  is the current node
# Current:  (2, 3), (4, 3), (4, 5), (13, 12), (11, 12), (11, 10)
# 12  is the current node
# in merge
# merge found  (13, 12)
# Current:  (2, 3), (4, 3), (4, 5), (11, 10)
# 3  is the current node
# 2 (4, 5) (4, 3)
# less
# 1
# (4, 3)
# Current:  (4, 5), (11, 10)
# 7  is the current node
# Current:  (4, 5), (7, 6), (7, 8), (11, 10)
# 5  is the current node
# in lower
# 3 (11, 10) (4, 5)
# less
# 2
# (7, 8)
# 1
# (7, 6)
# 0
# (4, 5)
# 3 (11, 10) (4, 5)
# less
# 2
# (7, 8)
# 1
# (7, 6)
# 0
# (4, 5)
# should find edge (11, 10)
# edge helper 7 split
# Current:  (5, 6), (7, 6), (7, 8), (11, 10)
# 10  is the current node
# Current:  (5, 6), (7, 6), (7, 8), (10, 9)
# 9  is the current node
# Current:  (5, 6), (7, 6), (7, 8), (9, 8)
# 6  is the current node
# Current:  (7, 8), (9, 8)
# 8  is the current node
# Current:

# %%
nx.draw(graph, nx.get_node_attributes(graph, 'pos'), with_labels=True, node_size=0)
plt.show()

# %%
print(p.vertices[3])
# Out:
# (-4.000000, -4.000000)

# %%
print(p.vertices[3].v_prev)
# Out:
# (-1.000000, -9.000000)

# %%
v1 = Vertex(-3,1, 1)
v2 = Vertex(0,0, 2)
v3 = Vertex(3,4, 3)
v4 = Vertex(-2,5, 4)
v5 = Vertex(-1,2, 5)


p = Polygon(v1, v2, v3)
p.add_vertex(v4)
p.add_vertex(v5)

# %%
p.create_graph()

# %%
graph = make_mono(p)
# Out:
# 1  is the current node
# Current:  (1, 2), (1, 5)
# 4  is the current node
# Current:  (1, 2), (1, 5), (4, 5), (4, 3)
# 5  is the current node
# in merge
# merge found  (1, 5)
# Current:  (1, 2), (4, 3)
# 2  is the current node
# in lower
# should find edge (4, 3)
# edge helper 4 start
# Current:  (2, 3), (4, 3)
# 3  is the current node
# Current:

# %%
nx.draw(graph, nx.get_node_attributes(graph, 'pos'), with_labels=True, node_size=0)
plt.show()
