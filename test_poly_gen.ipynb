# %%
from generate_polygon import *

# %%
p = generate_polygon(-6, 6)

# %%
from make_monotone import *
graph = make_mono(p)
# Out:
# 6  is the current node
# in start start
# Current:  (6, 7), (6, 5)
# 3  is the current node
# in start start
# Current:  (6, 7), (6, 5), (3, 4), (3, 2)
# 8  is the current node
# in start start
# Current:  (8, 9), (8, 7), (6, 7), (6, 5), (3, 4), (3, 2)
# 4  is the current node
# in lower
# testing  (8, 9) (8, 7)
# testing  (8, 7) (6, 7)
# testing  (6, 7) (6, 5)
# testing  (6, 5) (3, 4)
# testing  (3, 4) (3, 2)
# Returning 5 (3, 2)
# Current:  (8, 9), (8, 7), (6, 7), (6, 5), (4, 5), (3, 2)
# 7  is the current node
# in merge
# testing  (8, 9) (8, 7)
# testing  (8, 7) (6, 7)
# testing  (6, 7) (6, 5)
# Returning 3 (6, 5)
# helper found for merge is  (-6.000000, 1.000000)
# Current:  (8, 9), (6, 5), (4, 5), (3, 2)
# 5  is the current node
# in merge
# testing  (8, 9) (6, 5)
# testing  (6, 5) (4, 5)
# testing  (4, 5) (3, 2)
# Returning 3 (3, 2)
# helper found for merge is  (-3.000000, 2.000000)
# Current:  (8, 9), (3, 2)
# 9  is the current node
# in lower
# testing  (8, 9) (3, 2)
# Returning 1 (3, 2)
# Current:  (9, 10), (3, 2)
# 2  is the current node
# in upper
# edge removed in upper,  (3, 2)
# Current:  (9, 10), (2, 1)
# 12  is the current node
# in split
# testing  (9, 10) (2, 1)
# Returning 1 (2, 1)
# names of edges we connect  12 2
# Current:  (9, 10), (12, 11), (12, 1), (2, 1)
# 10  is the current node
# in lower
# testing  (9, 10) (12, 11)
# Returning 1 (12, 11)
# 3 (2, 1) (9, 10)
# less
# 2
# (12, 1)
# 1
# (12, 11)
# 0
# (9, 10)
# Current:  (10, 11), (12, 11), (12, 1), (2, 1)
# 1  is the current node
# in end 1
# Current:  (10, 11), (12, 11)
# 11  is the current node
# in end 11
# Current:

# %%
nx.draw(graph, nx.get_node_attributes(graph, 'pos'), with_labels=True, node_size=0)
plt.show()

# %%
p2 = generate_polygon(-4, 4)

# %%
graph2 = make_mono(p2)
# Out:
# 5  is the current node
# in start start
# Current:  (5, 6), (5, 4)
# 4  is the current node
# in upper
# edge removed in upper,  (5, 4)
# Current:  (5, 6), (4, 3)
# 6  is the current node
# in lower
# testing  (5, 6) (4, 3)
# Returning 1 (4, 3)
# Current:  (6, 7), (4, 3)
# 3  is the current node
# in upper
# edge removed in upper,  (4, 3)
# Current:  (6, 7), (3, 2)
# 2  is the current node
# in upper
# edge removed in upper,  (3, 2)
# Current:  (6, 7), (2, 1)
# 7  is the current node
# in lower
# testing  (6, 7) (2, 1)
# Returning 1 (2, 1)
# Current:  (7, 8), (2, 1)
# 1  is the current node
# in upper
# edge removed in upper,  (2, 1)
# Current:  (7, 8), (1, 8)
# 8  is the current node
# in end 8
# Current:

# %%
nx.draw(graph2, nx.get_node_attributes(graph2, 'pos'), with_labels=True, node_size=0)
plt.show()
